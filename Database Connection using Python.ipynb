# %% [markdown]
# #                                 **DATABASE COMMUNICATION**

# %% [markdown]
# **Prerequisites:** Basic Python Programming, DBMS(Fundamentals), MySQL(fundamentals).<br>
#     For any assistance related to above prerequisites you can contact:<br>
#     <font color=maroon>Python: Dr.D.P.Sharma(Dept of IT,MUJ)<br></font>
#     <font color=maroon>DBMS: Krishna Kumar/Shashank Sharma(Dept of IT,MUJ)<br></font>
#     <font color=maroon>MySQL: Krishna Kumar/Shashank Sharma(Dept of IT,MUJ)<br></font>

# %% [markdown]
# For every application it is mandatory to store the information permanently. And it is possible to store data by using
# - File System(File Handling)<br>
# - DBMS

# %% [markdown]
# The Python standard for database interface is the Python DB-API. Most Python databases adhere to this standard.You can choose the right database for your application.<br>
# Python Database API supports a wide range of databse servers.<br>
# 1.MySQL<br>
# 2.Microsoft SQL Server 2000<br>
# 3.Infoix<br>
# 4.Oracle<br>
# 5.Sybase<br>
#
# The DB API provides a minimal standard for working with databases using Python structures and syntax wherever possible.Following are the steps:<br>
# - Importing the API module.<br>
# - Accquiring a connection with databse.<br>
# - Issuing SQL statements and stored procedures.<br>
# - Closing the connenction.<br>

# %% [markdown]
# **Little about Database?**
#
# A databse is a separate application that stores a collection of data. Each databse has one or more distinct APIs for creating, accessing, managing, searching, and replicating the data it holds. Relational Data Base Management Systems to store and manage huge volume of data.

# %% [markdown]
# **RDBMS Terminology**
#
# Databse<br>
# Column<br>
# Row<br>
# Redundancy<br>
# Primary Key<br>
# Foreign Key<br>
# Compound Key<br>
# Index<br>
# Referential Integriti<br>

# %% [markdown]
# **MySQL Database**<br>
# 1.MySQL is a fast,easy to use RDBMS being used for many small and big businesses.<br>
# 2.MySQL is released under and open source license. So you have to pay nothing to use it.<br>
# 3.MySQL uses a standard form of well known SQL data languange.<br>
# 4.MySQL works on many operating systems and with many languages.<br>
# 5.MySQL works very quickly and works well even with large data sets.<br>
# 6.MySQL is customizable.<br>

# %% [markdown]
# **How do I install MySQLdb?**
#
# Before proceeding, you make sure you have MySQLdb installed on your machine. Just type the following in your Python script and execute it.<br>
# __http://pythonanywhere.com__<br>
# PythonAnywhere is an online integrated development environment (IDE) and web hosting service (Platform as a service) based on the Python programming language.<br>
# ![Screenshot%20from%202018-11-22%2012-32-54.png](attachment:Screenshot%20from%202018-11-22%2012-32-54.png)<br>
# Create your account and enjoy the joy of computing using Python :-)

# %% [markdown]
# **Installing MySQL connnector for python**<br>
# Goto: __https://dev.mysql.com/downloads/connector/python/__
# ![Screenshot%20from%202018-11-22%2012-30-53.png](attachment:Screenshot%20from%202018-11-22%2012-30-53.png)<br>
# and download accordingly to your Python version installed.

# %% [markdown]
# **Basic MySQL synatax**
#
# create database databse_name; <br>
# show databses;<br>
# use database_name;<br>
# create table table_name(eid int,ename varchar(50));<br>
# show tables;<br>
# drop table table_name;<br>
# insert into table_name(12345,"mohit";<br>
# update table_name=(5678,"shubhranshu");<br>
# delete from table_name where name="mohit";<br>
# for any assistance related to MySQL visit: __http://www.mysqltutorial.org/__<br>
#                                       &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&nbsp;     __https://www.w3schools.com/sql/__<br>

# %% [markdown]
# **Connecting to MySQLdb from Python**
#
# After successful creating and updating ...!!<br>
#
# MySQL related functionalities is provided in *"mysql"* module.So we need to import the module in order to<br>      work with our databse.<br>
#
# *connect()*<br>
# &emsp;&emsp;&emsp;&emsp;is a predefined module available in connector module which is sub module of *"mysql"* which       <br>               &emsp;&emsp;&emsp;&emsp;estalblishes connection between the databse and our Pyhton program.<br>
# *connect()*<br>
# &emsp;&emsp;&emsp;&emsp;function takes 4 argument as to connect with database.<br>
#             &emsp;&emsp;&emsp;&emsp;connect(user_name,password,host_system_of_Database,databse_name)
#
#
# In general:<br>                                                                                                &emsp;&emsp;&emsp;&emsp;&emsp;username="MySQL_username",password="MySql_password",host_system_of_Database="127.0.0.1/localhost"<br>           &emsp;&emsp;&emsp;&emsp;&emsp;,database_name="databaseName"<br>

# %%
#let's connect
import mysql.connectors
class DBConnect:
    def openConnction():
        mysql.connectors.connect(user="root",password="root",host="127.0.0.1",database="student")
        print("connection established")
        return
DBConnect.openConnection()

# %% [markdown]
# *cursor()*<br>
#    - We can execute statements(queries) in hte database using the objext which is returned by cursor()             method.<br>
#    - It must be called on connection object which is returned by connect method.<br>
#    - execute() method can be used to execute all types of sql queries.<br>

# %%
import mysql.connector
class DBConnect:
    con=" " 
    def open():
        try:
            DBConnect.con=mysql.connector.connect(ser="root",password="root",host="127.0.0.1",database="student")
            cur=DB.con.cursor()
            cur.execute("create table test(no int)")
            print("Table created...")
            cur.executed("drop table test")
            print("Table deleted successfully...")
        except Exception as e:
            print("Exception: ",e)
        finally:
            if DBConnect.con != " "
            DBConnect.con.close()
            print("Connection closed")
def main():
    DBConnect.open()
    return

# %% [markdown]
# **Reading Information from database table.**<br>
# *fetchone()*<br>
#  - A predefined function is used to access only one record from the table.
#  - DRL(Database Retrieval Language) command(select) the information will be stored into the cursor               object.
#  - Hence we can execute different methods on that cursor object t access the data.

# %% [markdown]
# ![Screenshot%20from%202018-11-22%2020-14-51.png](attachment:Screenshot%20from%202018-11-22%2020-14-51.png)

# %%
cur=DBConnect.con.cursor()
cur.execute("select * from account")
row=cur.fetchone()
print(row) #one tuple data is printed
data=cur.fetchall() #all the tuples are printed
for row in data:
    print(row)

# %% [markdown]
# **Using where clause**<br>
# - Reading balance form the account by specifying account number.

# %%
no=int(input("Enter account number: "))
cur.execute("select balance from account where accno=",+str(no))
balance=cur.fetchone()
print(balance)

# %% [markdown]
# **Updating the record in database talbe**<br>
# <font color=red>_Note: In the database DML command must be commited explicitly from application._<br></font>
# ![Screenshot%20from%202018-11-22%2018-38-54.png](attachment:Screenshot%20from%202018-11-22%2018-38-54.png)

# %%
no=int(input("Enter account number: "))
amt=int(input("Enter deposit amount: "))
cur.execute("select balance form account where acno=",+str(no))
row=cur.fetchone()
bal=bal[0]
bal=bal+amt
cur.execute("update account set balance="+str(bal)+"where accno="+str(no))
DBConnect.con.commit()
print("Record updated")

# %% [markdown]
# **Commit and Rollback**<br>
# <font color=red>_Note: In MySQL database all the DML operations will be saved permanently after executing a query._<br></font><br>
#
# If we want to save the record only when we commit explicitly then we need to execute the query as follows:<br>
# <br>
# >set.autocommit=0;<br>
# >select * from account;<br>
# >insert into account values()  <font color=lightblue>//record will be stored temporarily</font><br>
# >select<span>*</span>;<br>
# >rollback;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font color=lightblue>//undo the last inserted record</font><br>
# >select all;<br>
# >insert()<br>
# >commit;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font color=lightblue>//now record saved permanently</font><br>
# >rollback;&emsp;&emsp;&emsp;&emsp;&nbsp;&emsp;&emsp;&emsp;<font color=lightblue>//no operation performed,cannot rollback after commmit</font><br>

# %% [markdown]
# **Executing Rollback and Commit from the Python application**<br>
#
# mysql.connector provides predefined methods to perform transactions using *rollback()* and *commit()* methods without going to MySQL applications. This reduces out a little bit of extra work.

# %%
Transaction.con.autocommit=False
print("auto commit made to false") # default value is True
cur=Transaction.con.cursor()
no=108
name="radhakrishna"
bal=50000
cur.execute("insert into account values()
